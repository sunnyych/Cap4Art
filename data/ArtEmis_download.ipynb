# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment2/'
FOLDERNAME = 'cs231n/project/WikiArt'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load

# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Mounted at /content/drive

# %%
from re import S
import pandas as pd
import os
import requests
from time import sleep
from urllib.parse import urlparse


BASE_DIR = "/content/drive/MyDrive/cs231n/project/WikiArt"
# 1. Read in the two CSV files
wiki_df = pd.read_csv(os.path.join(BASE_DIR, "wikiart_scraped.csv"))
artemis_df0 = pd.read_csv(os.path.join(BASE_DIR, 'artemis_dataset_release_v0.csv'))
# 2. Filter Artemis to only rows with repetition >= 5
artemis_df = artemis_df0[artemis_df0['repetition'] >= 5].copy()

# %%
import pandas as pd
import os
from urllib.parse import urlparse


# 3. Helper functions to parse and build token keys
def parse_wiki_link(url):
    """
    Given a WikiArt link like:
      https://uploads3.wikiart.org/images/vincent-van-gogh/l-arlesienne-portrait-of-madame-ginoux-1890.jpg
    Returns (artist_folder, painting_name_no_ext), both lowercase.
    """
    path = urlparse(url).path
    parts = path.strip('/').split('/')
    if len(parts) < 2:
        return None, None
    artist_folder = parts[-2].lower()
    filename = parts[-1]
    painting_name, _ = os.path.splitext(filename)
    return artist_folder, painting_name.lower()

def parse_artemis_painting(p):
    """
    Given Artemis 'painting' like:
      vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
    Returns (artist_part, painting_part), both lowercase.
    """
    if not isinstance(p, str) or '_' not in p:
        return None, None
    artist_part, painting_part = p.split('_', 1)
    return artist_part.lower(), painting_part.lower()

def token_key(s):
    """
    Splits on '-' and sorts tokens alphabetically, then joins with spaces.
    Ensures that ordering differences don't break a match.
    """
    tokens = [tok for tok in s.split('-') if tok]
    return ' '.join(sorted(tokens))

# 4. Parse both DataFrames into (artist, painting) and compute token_key
wiki_df[['wiki_artist', 'wiki_painting']] = wiki_df['Link'].apply(
    lambda u: pd.Series(parse_wiki_link(u))
)
artemis_df[['artemis_artist', 'artemis_painting']] = artemis_df['painting'].apply(
    lambda p: pd.Series(parse_artemis_painting(p))
)

# 5. Drop any rows where parsing failed
wiki_filtered = wiki_df.dropna(subset=['wiki_artist', 'wiki_painting']).copy()
artemis_filtered = artemis_df.dropna(subset=['artemis_artist', 'artemis_painting']).copy()

# 6. Build token_key for painting names
wiki_filtered['wiki_key'] = wiki_filtered['wiki_painting'].map(token_key)
artemis_filtered['artemis_key'] = artemis_filtered['artemis_painting'].map(token_key)

# 7. Deduplicate wiki_filtered by (wiki_artist, wiki_key)
wiki_unique = wiki_filtered.drop_duplicates(subset=['wiki_artist', 'wiki_key'])[
    ['wiki_artist', 'wiki_key', 'Link']
]

# 8. Deduplicate Artemis_filtered by (artemis_artist, artemis_key)
artemis_unique = artemis_filtered.drop_duplicates(subset=['artemis_artist', 'artemis_key']).copy()

# 9. Merge Artemis_unique with Wiki_unique on (artist, key)
merged = pd.merge(
    artemis_unique,
    wiki_unique,
    left_on=['artemis_artist', 'artemis_key'],
    right_on=['wiki_artist', 'wiki_key'],
    how='inner'
)
# 10a. Extract unique URLs and assign each a unique integer index
unique_links = (
    merged[['Link']]
    .drop_duplicates()
    .reset_index(drop=True)
    .rename(columns={'Link': 'url'})
)
unique_links['url_id'] = unique_links.index  # 0, 1, 2, …

# 10b. Merge url_id back onto merged via the URL
merged = merged.merge(unique_links, left_on='Link', right_on='url', how='left')

# 11. Now merge back to artemis_filtered to keep all original rows (emotion, art_style, etc.)
artemis_merged = pd.merge(
    artemis_filtered,
    merged[['url_id', 'Link', 'wiki_artist', 'wiki_key']],
    left_on=['artemis_artist', 'artemis_key'],
    right_on=['wiki_artist', 'wiki_key'],
    how='inner'
)

print("Number of rows in merged:", merged.shape[0])
print("Number of unique URLs:", merged['Link'].nunique())
print("Number of unique url_ids:", merged['url_id'].nunique())

# 12. Drop fully duplicate rows
artemis_unique_rows = artemis_merged.drop_duplicates().copy()

# 13. Create a new column combining art_style and emotion
artemis_unique_rows['style_emotion'] = (
    artemis_unique_rows['art_style'] + '_' + artemis_unique_rows['emotion']
)

# 14. Save to CSV
print("Saving to CSV...")
output_path = os.path.join(BASE_DIR, 'artemis_with_style_emotion.csv')
artemis_unique_rows.to_csv(output_path, index=False)
print("Done Saving.")

#  Distribution of emotion alone
if 'emotion' in artemis_unique_rows.columns:
    counts_per_emotion = (
        artemis_unique_rows['emotion']
        .value_counts()
        .reset_index()
        .rename(columns={'index': 'emotion', 'emotion': 'url_count'})
    )
    print("\nURLs per emotion label:")
    print(counts_per_emotion.to_string(index=False))
else:
    print("\nNo 'emotion' column found in the unique set.")

# 15. Distribution of the new combined style_emotion column
counts_per_style_emotion = (
    artemis_unique_rows['style_emotion']
    .value_counts()
    .reset_index()
    .rename(columns={'index': 'style_emotion', 'style_emotion': 'count'})
)
print("\nURLs per (style x emotion) combined label:")
print(counts_per_style_emotion.to_string(index=False))

# 16. Print summary of sizes
print(f"\nwiki_df rows:                          {wiki_df.shape[0]}  cols: {wiki_df.shape[1]}")
print(f"artemis_df (original) rows:           {artemis_df.shape[0]}  cols: {artemis_df.shape[1]}")
print(f"artemis_df (repetition >= 5) rows:    {artemis_filtered.shape[0]}  cols: {artemis_filtered.shape[1]}")
print(f"artemis_unique (one per painting) rows: {artemis_unique.shape[0]}  cols: {artemis_unique.shape[1]}")
print(f"merged rows (one per painting):       {merged.shape[0]}  cols: {merged.shape[1]}")
print(f"artemis_unique_rows (fully unique)    {artemis_unique_rows.shape[0]}  cols: {artemis_unique_rows.shape[1]}")
print(f"Unique paintings in Artemis (rep>=5): {artemis_filtered['painting'].nunique()}")
print(f"Unique paintings in merged:           {merged['painting'].nunique()}")
# Out:
# Number of rows in merged: 43640
# Number of unique URLs: 43640
# Number of unique url_ids: 43640
# Saving to CSV...
# Done Saving.
#
# URLs per emotion label:
#      url_count  count
#    contentment  61222
#            awe  38982
# something else  32172
#      amusement  28961
#        sadness  25896
#           fear  23557
#     excitement  20981
#        disgust  13827
#          anger   4462
#
# URLs per (style x emotion) combined label:
#                                     count  count
#                 Impressionism_contentment   8850
#            Post_Impressionism_contentment   6729
#                       Realism_contentment   5764
#                        Rococo_contentment   3333
#                 Expressionism_contentment   3270
#                     Symbolism_contentment   3061
#            Art_Nouveau_Modern_contentment   2999
#                         Impressionism_awe   2989
#                             Symbolism_awe   2965
#                  Northern_Renaissance_awe   2958
#                   Romanticism_contentment   2886
#                               Realism_awe   2830
#     Abstract_Expressionism_something else   2822
#                       Baroque_contentment   2645
#                    Post_Impressionism_awe   2611
#         Naive_Art_Primitivism_contentment   2545
#                               Baroque_awe   2485
#       Color_Field_Painting_something else   2468
#                                Rococo_awe   2455
#                     Expressionism_sadness   2424
#           Naive_Art_Primitivism_amusement   2411
#                        Expressionism_fear   2393
#          Northern_Renaissance_contentment   2381
#                            Symbolism_fear   2355
#                 Minimalism_something else   2330
#                           Realism_sadness   2222
#                   Expressionism_amusement   2216
#                           Romanticism_awe   2150
#              Expressionism_something else   2110
#          Color_Field_Painting_contentment   2061
#        Abstract_Expressionism_contentment   2050
#                        Cubism_contentment   2021
#         Post_Impressionism_something else   2016
#              Art_Nouveau_Modern_amusement   1990
#                     Impressionism_sadness   1971
#                     Early_Renaissance_awe   1918
#                         Pop_Art_amusement   1914
#                          Cubism_amusement   1889
#                    Art_Nouveau_Modern_awe   1889
#                           Baroque_sadness   1886
#                         Symbolism_sadness   1849
#              Northern_Renaissance_sadness   1837
#                Post_Impressionism_sadness   1820
#         Abstract_Expressionism_excitement   1794
#                     Cubism_something else   1772
#                      High_Renaissance_awe   1763
#                         Expressionism_awe   1670
#            Mannerism_Late_Renaissance_awe   1669
#               Abstract_Expressionism_fear   1652
#         Art_Nouveau_Modern_something else   1612
#                 Northern_Renaissance_fear   1604
#                  Impressionism_excitement   1604
#             Post_Impressionism_excitement   1585
#            Abstract_Expressionism_disgust   1579
#                  Symbolism_something else   1572
#                         Baroque_amusement   1571
#              Impressionism_something else   1559
#                    Realism_something else   1553
#          Abstract_Expressionism_amusement   1536
#            Northern_Renaissance_amusement   1525
#              Post_Impressionism_amusement   1498
#                     Expressionism_disgust   1466
#                          Rococo_amusement   1445
#                              Realism_fear   1409
#                          Romanticism_fear   1406
#                Abstract_Expressionism_awe   1370
#       Northern_Renaissance_something else   1368
#                    Baroque_something else   1349
#                       Ukiyo_e_contentment   1339
#                              Baroque_fear   1339
#                                Cubism_awe   1327
#      Naive_Art_Primitivism_something else   1322
#                         Cubism_excitement   1295
#                   Post_Impressionism_fear   1294
#                        Pop_Art_excitement   1282
#                    Pop_Art_something else   1281
#                  Expressionism_excitement   1275
#                    Minimalism_contentment   1256
#                   Art_Nouveau_Modern_fear   1238
#             Art_Nouveau_Modern_excitement   1237
#                 Early_Renaissance_sadness   1220
#                 Naive_Art_Primitivism_awe   1218
#             Early_Renaissance_contentment   1209
#                   Impressionism_amusement   1184
#                       Romanticism_sadness   1179
#                         Ukiyo_e_amusement   1156
#                Naive_Art_Primitivism_fear   1149
#                     Rococo_something else   1141
#            Color_Field_Painting_amusement   1138
#                   Pointillism_contentment   1099
#                       Pop_Art_contentment   1068
#           Color_Field_Painting_excitement   1065
#              High_Renaissance_contentment   1057
#          Naive_Art_Primitivism_excitement   1055
#        Mannerism_Late_Renaissance_sadness   1051
#                      Symbolism_excitement   1048
#                       Symbolism_amusement   1036
#                Romanticism_something else   1031
#                               Ukiyo_e_awe   1029
#                Art_Nouveau_Modern_sadness   1014
#                        Impressionism_fear   1014
#                       Fauvism_contentment    999
#                  High_Renaissance_sadness    990
#                        Realism_excitement    973
#                     Romanticism_amusement    970
#           Mannerism_Late_Renaissance_fear    956
#                         Realism_amusement    947
#                Post_Impressionism_disgust    936
#          Contemporary_Realism_contentment    935
#                      Minimalism_amusement    928
#                            Rococo_sadness    924
#             Naive_Art_Primitivism_sadness    904
#          Early_Renaissance_something else    881
#              Northern_Renaissance_disgust    879
#    Mannerism_Late_Renaissance_contentment    868
#           High_Renaissance_something else    833
#                               Pop_Art_awe    807
#                               Cubism_fear    790
#            Abstract_Expressionism_sadness    774
#           Northern_Renaissance_excitement    770
#             Naive_Art_Primitivism_disgust    759
#                         Rococo_excitement    748
# Mannerism_Late_Renaissance_something else    743
#                    Romanticism_excitement    735
#                     High_Renaissance_fear    734
#                              Ukiyo_e_fear    725
#              Color_Field_Painting_disgust    723
#                    Ukiyo_e_something else    721
#                High_Renaissance_amusement    709
#                        Baroque_excitement    705
#                            Cubism_sadness    701
#                               Rococo_fear    695
#                           Baroque_disgust    695
#                         Symbolism_disgust    693
#                            Cubism_disgust    685
#                         Fauvism_amusement    677
#      Mannerism_Late_Renaissance_amusement    674
#                        Ukiyo_e_excitement    660
#                    Early_Renaissance_fear    637
#                  Color_Field_Painting_awe    599
#              Abstract_Expressionism_anger    583
#               Early_Renaissance_amusement    579
#                        Fauvism_excitement    570
#                        Minimalism_sadness    568
#                     Impressionism_disgust    568
#                           Pop_Art_disgust    559
#                Art_Nouveau_Modern_disgust    528
#              Color_Field_Painting_sadness    514
#                 Color_Field_Painting_fear    501
#                  Contemporary_Realism_awe    489
#                   New_Realism_contentment    483
#                              Pop_Art_fear    465
#                           Pointillism_awe    464
#                           Pop_Art_sadness    461
#                     Minimalism_excitement    450
#                            Rococo_disgust    448
#                        Minimalism_disgust    446
#                            Minimalism_awe    445
#                           Realism_disgust    431
#                Color_Field_Painting_anger    425
#                               Fauvism_awe    414
#                           Ukiyo_e_sadness    413
#                       Romanticism_disgust    402
#        Mannerism_Late_Renaissance_disgust    390
#              Early_Renaissance_excitement    369
#               High_Renaissance_excitement    368
#                    Fauvism_something else    364
#                           Minimalism_fear    358
#                  High_Renaissance_disgust    354
#                          Minimalism_anger    346
#                 Early_Renaissance_disgust    344
#     Mannerism_Late_Renaissance_excitement    332
#           Synthetic_Cubism_something else    331
#                           Ukiyo_e_disgust    325
#              Contemporary_Realism_sadness    318
#                    Pointillism_excitement    316
#       Contemporary_Realism_something else    310
#                       Expressionism_anger    300
#           Contemporary_Realism_excitement    251
#            Contemporary_Realism_amusement    250
#                       New_Realism_sadness    249
#                Northern_Renaissance_anger    248
#                           New_Realism_awe    233
#                Pointillism_something else    226
#                 Contemporary_Realism_fear    221
#                  Post_Impressionism_anger    216
#                     Pointillism_amusement    212
#              Synthetic_Cubism_contentment    210
#                           Fauvism_sadness    208
#                       Pointillism_sadness    206
#                Synthetic_Cubism_amusement    197
#                New_Realism_something else    196
#                              Cubism_anger    190
#                     New_Realism_amusement    190
#                              Fauvism_fear    182
#                             Ukiyo_e_anger    181
#                    New_Realism_excitement    181
#                             Baroque_anger    181
#                           Symbolism_anger    174
#                           Fauvism_disgust    171
#               Synthetic_Cubism_excitement    168
#               Naive_Art_Primitivism_anger    160
#                  Art_Nouveau_Modern_anger    156
#                    High_Renaissance_anger    155
#                             Pop_Art_anger    153
#                             Realism_anger    151
#                          New_Realism_fear    146
#                              Rococo_anger    142
#              Contemporary_Realism_disgust    141
#          Analytical_Cubism_something else    135
#                   Early_Renaissance_anger    133
#          Mannerism_Late_Renaissance_anger    129
#                         Romanticism_anger    126
#            Action_painting_something else    126
#                      Synthetic_Cubism_awe    119
#                       Impressionism_anger    115
#                          Pointillism_fear     95
#                     Analytical_Cubism_awe     87
#                Action_painting_excitement     85
#                  Synthetic_Cubism_sadness     81
#                  Synthetic_Cubism_disgust     77
#                      Action_painting_fear     74
#                 Analytical_Cubism_sadness     71
#                   Action_painting_disgust     69
#                 Analytical_Cubism_disgust     66
#                    Analytical_Cubism_fear     63
#                     Synthetic_Cubism_fear     62
#               Analytical_Cubism_amusement     60
#              Analytical_Cubism_excitement     60
#                 Action_painting_amusement     59
#             Analytical_Cubism_contentment     59
#                     Action_painting_anger     57
#                       New_Realism_disgust     55
#               Action_painting_contentment     45
#                   Action_painting_sadness     41
#                             Fauvism_anger     40
#                       Pointillism_disgust     38
#                    Synthetic_Cubism_anger     34
#                Contemporary_Realism_anger     33
#                       Action_painting_awe     29
#                         Pointillism_anger     15
#                         New_Realism_anger     10
#                   Analytical_Cubism_anger      9
#
# wiki_df rows:                          124170  cols: 7
# artemis_df (original) rows:           454684  cols: 7
# artemis_df (repetition >= 5) rows:    454684  cols: 8
# artemis_unique (one per painting) rows: 80003  cols: 8
# merged rows (one per painting):       43640  cols: 13
# artemis_unique_rows (fully unique)    250060  cols: 13
# Unique paintings in Artemis (rep>=5): 80031
# Unique paintings in merged:           43640

# %%
merged['url_id'].value_counts()
# Out:
# url_id
# 43639    1
# 0        1
# 1        1
# 2        1
# 3        1
#         ..
# 12       1
# 11       1
# 10       1
# 9        1
# 8        1
# Name: count, Length: 43640, dtype: int64

# %%
import os
import requests
from urllib.parse import urlparse
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm  # for a progress bar

# 1. Ensure SAVE_DIR exists
SAVE_DIR = os.path.join(BASE_DIR, 'artemis_images')
os.makedirs(SAVE_DIR, exist_ok=True)

# 2. Prepare a list of (url_id, url) for each row in `merged`
#    merged must already have a unique 'url_id' column and a 'Link' column
urls_to_download = list(zip(merged['url_id'], merged['Link']))

def download_one(item):
    """
    Downloads a single (url_id, url) tuple.
    Saves file as "<url_id>.<ext>" (e.g. "0.jpg").
    Returns None on success or (url_id, url, error_msg) on failure.
    """
    url_id, url = item
    ext = os.path.splitext(urlparse(url).path)[1]  # e.g. ".jpg" or ".png"
    save_name = f"{url_id}{ext}"
    save_path = os.path.join(SAVE_DIR, save_name)

    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
        with open(save_path, 'wb') as f:
            f.write(r.content)
        return None
    except Exception as e:
        return (url_id, url, str(e))

# 3. Download in parallel
MAX_WORKERS = 20
failed = []

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(download_one, item): item for item in urls_to_download}
    for fut in tqdm(as_completed(futures), total=len(futures), desc="Downloading"):
        result = fut.result()
        if result is not None:
            failed.append(result)

# 4. Print summary
total = len(urls_to_download)
success = total - len(failed)
print(f"\nTotal attempted: {total}")
print(f"Downloaded successfully: {success}")
print(f"Failed downloads: {len(failed)}")
if failed:
    print("Some failure examples:", failed[:5])
# Out:
# Downloading: 100%|██████████| 43640/43640 [38:41<00:00, 18.80it/s]
# Total attempted: 43640
# Downloaded successfully: 43608
# Failed downloads: 32
# Some failure examples: [(4394, 'https://uploads6.wikiart.org/images/sam-francis/untitled-1953-1.jpg', '520 Server Error: <none> for url: https://uploads6.wikiart.org/images/sam-francis/untitled-1953-1.jpg'), (6802, 'https://uploads2.wikiart.org/images/egon-schiele/self-portrait-with-hand-to-cheek-1910.jpg', '520 Server Error: <none> for url: https://uploads2.wikiart.org/images/egon-schiele/self-portrait-with-hand-to-cheek-1910.jpg'), (8535, 'https://uploads4.wikiart.org/images/forrest-bess/it-fits-1955.jpg', '520 Server Error: <none> for url: https://uploads4.wikiart.org/images/forrest-bess/it-fits-1955.jpg'), (11494, 'https://uploads0.wikiart.org/images/paul-gauguin/breton-woman-1886.jpg', '520 Server Error: <none> for url: https://uploads0.wikiart.org/images/paul-gauguin/breton-woman-1886.jpg'), (12068, 'https://uploads3.wikiart.org/images/rembrandt/the-shepards-and-the-family-1644.jpg', '520 Server Error: <none> for url: https://uploads3.wikiart.org/images/rembrandt/the-shepards-and-the-family-1644.jpg')]
